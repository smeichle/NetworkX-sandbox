# %% [markdown]
# ___
# ## Network Analysis with NetworkX
# ## Simulating a social network (ie; directed network analysis)

# %%
import numpy as np
import pandas as pd

import networkx as nx

import matplotlib.pyplot as plt
from pylab import rcParams
import seaborn as sb

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 6, 5
sb.set_style('whitegrid')

# %% [markdown]
# ### Generate a graph object and edgelist

# %%
DG = nx.gn_graph(7, seed=25)

for line in nx.generate_edgelist(DG, data=False): print(line)
# Out:
# 1 0
# 2 0
# 3 2
# 4 3
# 5 0
# 6 4

# %% [markdown]
# ### Assign attributes to nodes

# %%
print(DG.node[0])
# Out:
# {}

# %%
DG.node[0]['name'] = 'Alice'

# %%
print(DG.node[0])
# Out:
# {'name': 'Alice'}

# %%
DG.node[1]['name'] = 'Bob'
DG.node[2]['name'] = 'John'
DG.node[3]['name'] = 'Dennis'
DG.node[4]['name'] = 'Esther'
DG.node[5]['name'] = 'Frank'
DG.node[6]['name'] = 'George'

# %%
DG.add_nodes_from([(0,{'age':25}),(1,{'age':31}),(2,{'age':18}),(3,{'age':47}),(4,{'age':22}),
                   (5,{'age':23}),(6,{'age':50})])
print(DG.node[0])
# Out:
# {'name': 'Alice', 'age': 25}

# %%
DG.node[0]['gender'] = 'f'
DG.node[1]['gender'] = 'm'
DG.node[2]['gender'] = 'f'
DG.node[3]['gender'] = 'm'
DG.node[4]['gender'] = 'f'
DG.node[5]['gender'] = 'm'
DG.node[6]['gender'] = 'm'

# %% [markdown]
# ### Visualize our network graph

# %%
nx.draw_circular(DG, node_color='bisque', with_labels=True)

# %%
labeldict = {0: 'Alice',1:'Bob',2:'Claire',3:'Dennis',4:'John',5:'Frank',6:'George'}

nx.draw_circular(DG, labels=labeldict, node_color='bisque', with_labels=True)

# %%
G = DG.to_undirected()

# %%
nx.draw_spectral(G, labels=labeldict, node_color='bisque', with_labels=True)
